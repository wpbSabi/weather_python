# %% [markdown]
# # Exploratory Data Analysis
# Initial data exploration
# * Update precipitation CSV with new data
# * View the beginning and end date of each station
# * View the locations of each station on a map

# %%
import numpy as np
import os
import pandas as pd
import sys
sys.path.append(os.path.dirname(os.getcwd()))

import functions

# %% [markdown]
# ## Option 1: Explore new weather stations

# %%
df = pd.read_csv('../data/raw_temp_chicago_stations.csv')[[
    'STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION',
]].drop_duplicates().reset_index(drop=True)
df
# Out:
#          STATION                                NAME   LATITUDE  LONGITUDE  \
# 0    US1ILCK0393          TINLEY PARK 1.2 WNW, IL US  41.582370 -87.821920
# 1    US1ILCK0150      ARLINGTON HEIGHTS 1.2 S, IL US  42.077974 -87.983814
# 2    USC00115097       LISLE MORTON ARBORETUM, IL US  41.812710 -88.072750
# 3    US1ILWL0173               LOCKPORT 5.0 W, IL US  41.579960 -88.143802
# 4    US1ILCK0390                  ALSIP 0.9 E, IL US  41.672600 -87.718100
# ..           ...                                 ...        ...        ...
# 168  US1ILCK0163     ARLINGTON HEIGHTS 1.2 SW, IL US  42.081944 -87.997116
# 169  US1ILDP0150         BLOOMINGDALE 1.2 ESE, IL US  41.939720 -88.066570
# 170  US1ILCK0278       HOFFMAN ESTATES 1.6 SE, IL US  42.048122 -88.116188
# 171  US1ILWL0149      BULT FIELD MONEE 4.9 SE, IL US  41.377400 -87.679750
# 172  USC00111577  CHICAGO MIDWAY AIRPORT 3 SW, IL US  41.737270 -87.777340
#
#      ELEVATION
# 0        215.8
# 1        208.8
# 2        206.3
# 3        192.9
# 4        182.0
# ..         ...
# 168      215.8
# 169      221.0
# 170      242.0
# 171      236.8
# 172      189.0
#
# [173 rows x 5 columns]

# %%
# # Optional - add these stations to the geo_data file
# df_geo_data = pd.read_csv('../data/geo_data.csv')
# df_new = pd.concat([df_geo_data, df])
# df_new.to_csv('../data/geo_data.csv')

# %%
# Map the stations 
functions.map_stations(
    df,
    default_lat=41.8,
    default_long=-87.5,
    default_zoom=9)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8966650532fcc6a14b3e8e5fa2ad5e5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8966650532fcc6a14b3e8e5fa2ad5e5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8966650532fcc6a14b3e8e5fa2ad5e5b = L.map(
#                 &quot;map_8966650532fcc6a14b3e8e5fa2ad5e5b&quot;,
#                 {
#                     center: [41.8, -87.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7954d5c0ca3448a0d7afa261be152450 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7954d5c0ca3448a0d7afa261be152450.addTo(map_8966650532fcc6a14b3e8e5fa2ad5e5b);
#
#
#             var circle_marker_4cb7220747e6e89f76986adc85a47c03 = L.circleMarker(
#                 [41.58237, -87.82192],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8966650532fcc6a14b3e8e5fa2ad5e5b);
#
#
#             circle_marker_4cb7220747e6e89f76986adc85a47c03.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      US1ILCK0393
# ELEVATION          215.8
# Name: 0, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e74e1e30db75b4fd942b4d415f0d201b = L.circleMarker(
#                 [42.077974, -87.983814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8966650532fcc6a14b3e8e5fa2ad5e5b);
#
#
#             circle_marker_e74e1e30db75b4fd942b4d415f0d201b.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      US1ILCK0150
# ELEVATION          208.8
# Name: 1, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b763cacc4cf2b7558a26f1abab499245 = L.circleMarker(
#                 [41.81271, -88.07275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8966650532fcc6a14b3e8e5fa2ad5e5b);
#
#
#             circle_marker_b763cacc4cf2b7558a26f1abab499245.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      USC00115097
# ELEVATION          206.3
# Name: 2, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_400db9f7c135d54620a587c032761472 = L.circleMarker(
#                 [41.57996, -88.143802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8966650532fcc6a14b3e8e5fa2ad5e5b);
#
#
#             circle_marker_400db9f7c135d54620a587c032761472.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      US1ILWL0173
# ELEVATION          192.9
# Name: 3, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_15e6affe2b4fef5318af1ad1b97c0aeb = L.circleMarker(
#                 [41.6726, -87.7181],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;das

# %% [markdown]
# ## Option 2: Add new data to an existing file

# %%
# Append new data to an existing file

# Import new weather data
NEW_DATA_TO_ADD_PATH = '../data/raw_precipitation_97016.csv'
EXISTING_DATA_PATH = '../data/precipitation_97016.csv'
df = functions.update_data(new_data_path=NEW_DATA_TO_ADD_PATH,
                           existing_data_path=EXISTING_DATA_PATH,
                           overwrite='yes')

# Import geospatial data and analyze the date range
station_dates = functions.view_station_date_ranges(df)
geo_data = functions.update_data(new_data_path='../data/geo_data.csv',
                 existing_data_path='../data/geo_data.csv',
                 overwrite='yes')

# The stations with recent history have geo_data available
station_dates.merge(geo_data, on=['STATION', 'NAME'], how='left')
# Out:
#        STATION                       NAME   min_date   max_date   LATITUDE  \
# 0  US1ORCB0013   CLATSKANIE 3.0 NE, OR US 1998-06-17 2024-06-28  46.131337
# 1  US1ORCB0027   CLATSKANIE 5.0 NE, OR US 2013-04-13 2016-01-04        NaN
# 2  US1ORCB0039  BIRKENFELD 3.1 NNW, OR US 2016-09-09 2017-01-18        NaN
# 3  US1ORCB0040   CLATSKANIE 8.8 SW, OR US 2017-05-30 2025-01-13  46.006917
# 4  US1ORCB0041    CLATSKANIE 6.1 W, OR US 2018-01-06 2025-01-13  46.115700
# 5  USC00351643          CLATSKANIE, OR US 1935-05-01 2024-12-31  46.108100
# 6  USC00355838       MOUNTAIN HOME, OR US 1909-06-01 1917-07-31        NaN
# 7  USC00359121               WAUNA, OR US 2011-01-01 2016-12-31        NaN
# 8  USR0000OMLL       MILLER OREGON, OR US 1996-10-17 2025-01-13  46.022800
#
#     LONGITUDE  ELEVATION
# 0 -123.157110       44.5
# 1         NaN        NaN
# 2         NaN        NaN
# 3 -123.324535      194.2
# 4 -123.331300        4.6
# 5 -123.205800        6.7
# 6         NaN        NaN
# 7         NaN        NaN
# 8 -123.271100      332.2

# %%
# Map the stations 
functions.map_stations(geo_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55fa361144794f78db57cb53424979d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55fa361144794f78db57cb53424979d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55fa361144794f78db57cb53424979d4 = L.map(
#                 &quot;map_55fa361144794f78db57cb53424979d4&quot;,
#                 {
#                     center: [46.082, -123.187],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19b43c136b46d0717b9bbaed1cca700c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19b43c136b46d0717b9bbaed1cca700c.addTo(map_55fa361144794f78db57cb53424979d4);
#
#
#             var circle_marker_343e3287c6480f944cfde903bf399ff4 = L.circleMarker(
#                 [46.0069167, -123.3245355],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_55fa361144794f78db57cb53424979d4);
#
#
#             circle_marker_343e3287c6480f944cfde903bf399ff4.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      US1ORCB0040
# ELEVATION          194.2
# Name: 0, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1488dece425ffcee07bd580038dd4b42 = L.circleMarker(
#                 [46.0228, -123.2711],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_55fa361144794f78db57cb53424979d4);
#
#
#             circle_marker_1488dece425ffcee07bd580038dd4b42.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      USR0000OMLL
# ELEVATION          332.2
# Name: 1, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_dc921caad6ce48d64efab7f05849a96c = L.circleMarker(
#                 [46.1157, -123.3313],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_55fa361144794f78db57cb53424979d4);
#
#
#             circle_marker_dc921caad6ce48d64efab7f05849a96c.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      US1ORCB0041
# ELEVATION            4.6
# Name: 2, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_7794fd6e594ed49178a3e2c4f0afcd48 = L.circleMarker(
#                 [46.131337, -123.15711],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkblue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_55fa361144794f78db57cb53424979d4);
#
#
#             circle_marker_7794fd6e594ed49178a3e2c4f0afcd48.bindTooltip(
#                 `&lt;div&gt;
#                      STATION      US1ORCB0013
# ELEVATION           44.5
# Name: 3, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_51f5580e361b1a195fcba836e9747ab9 = L.circleMarker(
#                 [46.1081, -123.2058],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;,
